# %%
# -*- coding: utf-8 -*-
"""
Created on Fri Nov 2 10:38:28 2018

@author: Shawnzy
"""

#%% Imports
import pandas as pd
import numpy as np
import sys
import matplotlib.pyplot as plt 

out = './'

# Cancer Dataset - 32 Attributes - 2 Classes

# %%
df = pd.read_hdf('./results.hdf','cancer_kmeans')

fig = plt.figure()
ax = df.plot(y='SSE', title="Cancer - Kmeans - SSE vs Number of Clusters")
ax.set(xlabel="Number of Clusters", ylabel="SSE")
plt.savefig('./Plots/cancer_k_sse.png')

fig = plt.figure()
ax = df.plot(y='ARI', title="Cancer - Kmeans - ARI vs Number of Clusters")
ax.set(xlabel="Number of Clusters", ylabel="ARI")
plt.savefig('./Plots/cancer_k_ari.png')

fig = plt.figure()
ax = df.plot(y='AMI', title="Cancer - Kmeans - AMI vs Number of Clusters")
ax.set(xlabel="Number of Clusters", ylabel="AMI")
plt.savefig('./Plots/cancer_k_ami.png')

fig = plt.figure()
ax = df.plot(y='HOM', title="Cancer - Kmeans - Homogeneity vs Number of Clusters")
ax.set(xlabel="Number of Clusters", ylabel="Homogeneity")
plt.savefig('./Plots/cancer_k_homo.png')

fig = plt.figure()
ax = df.plot(y='COM', title="Cancer - Kmeans - Completeness vs Number of Clusters")
ax.set(xlabel="Number of Clusters", ylabel="Completeness")
plt.savefig('./Plots/cancer_k_comp.png')

fig = plt.figure()
ax = df.plot(y='SIL', title="Cancer - Kmeans - Silhouette Score vs Number of Clusters")
ax.set(xlabel="Number of Clusters", ylabel="Silhouette Score")
plt.savefig('./Plots/cancer_k_silh.png')

# %%
df = pd.read_hdf('./results.hdf','cancer_expmax')

fig = plt.figure()
ax = df.plot(y='LGL', title="Cancer - EM - Log Likelihood vs Number of Clusters")
ax.set(xlabel="Number of Clusters", ylabel="Log Likelihood")
plt.savefig('./Plots/cancer_em_lgl.png')

fig = plt.figure()
ax = df.plot(y='ARI', title="Cancer - EM - ARI vs Number of Clusters")
ax.set(xlabel="Number of Clusters", ylabel="ARI")
plt.savefig('./Plots/cancer_em_ari.png')

fig = plt.figure()
ax = df.plot(y='AMI', title="Cancer - EM - AMI vs Number of Clusters")
ax.set(xlabel="Number of Clusters", ylabel="AMI")
plt.savefig('./Plots/cancer_em_ami.png')

fig = plt.figure()
ax = df.plot(y='HOM', title="Cancer - EM - Homogeneity vs Number of Clusters")
ax.set(xlabel="Number of Clusters", ylabel="Homogeneity")
plt.savefig('./Plots/cancer_em_homo.png')

fig = plt.figure()
ax = df.plot(y='COM', title="Cancer - EM - Completeness vs Number of Clusters")
ax.set(xlabel="Number of Clusters", ylabel="Completeness")
plt.savefig('./Plots/cancer_em_comp.png')

fig = plt.figure()
ax = df.plot(y='SIL', title="Cancer - EM - Silhouette Score vs Number of Clusters")
ax.set(xlabel="Number of Clusters", ylabel="Silhouette Score")
plt.savefig('./Plots/cancer_em_silh.png')

# %%
df = pd.read_hdf('./results.hdf','madelon_kmeans')

fig = plt.figure()
ax = df.plot(y='SSE', title="Madelon - Kmeans - SSE vs Number of Clusters")
ax.set(xlabel="Number of Clusters", ylabel="SSE")
plt.savefig('./Plots/madelon_k_sse.png')

fig = plt.figure()
ax = df.plot(y='ARI', title="Madelon - Kmeans - ARI vs Number of Clusters")
ax.set(xlabel="Number of Clusters", ylabel="ARI")
plt.savefig('./Plots/madelon_k_ari.png')

fig = plt.figure()
ax = df.plot(y='AMI', title="Madelon - Kmeans - AMI vs Number of Clusters")
ax.set(xlabel="Number of Clusters", ylabel="AMI")
plt.savefig('./Plots/madelon_k_ami.png')

fig = plt.figure()
ax = df.plot(y='HOM', title="Madelon - Kmeans - Homogeneity vs Number of Clusters")
ax.set(xlabel="Number of Clusters", ylabel="Homogeneity")
plt.savefig('./Plots/madelon_k_homo.png')

fig = plt.figure()
ax = df.plot(y='COM', title="Madelon - Kmeans - Completeness vs Number of Clusters")
ax.set(xlabel="Number of Clusters", ylabel="Completeness")
plt.savefig('./Plots/madelon_k_comp.png')

fig = plt.figure()
ax = df.plot(y='SIL', title="Madelon - Kmeans - Silhouette Score vs Number of Clusters")
ax.set(xlabel="Number of Clusters", ylabel="Silhouette Score")
plt.savefig('./Plots/madelon_k_silh.png')

# %%
df = pd.read_hdf('./results.hdf','madelon_expmax')

fig = plt.figure()
ax = df.plot(y='LGL', title="Madelon - EM - Log Likelihood vs Number of Clusters")
ax.set(xlabel="Number of Clusters", ylabel="Log Likelihood")
plt.savefig('./Plots/madelon_em_lgl.png')

fig = plt.figure()
ax = df.plot(y='ARI', title="Madelon - EM - ARI vs Number of Clusters")
ax.set(xlabel="Number of Clusters", ylabel="ARI")
plt.savefig('./Plots/madelon_em_ari.png')

fig = plt.figure()
ax = df.plot(y='AMI', title="Madelon - EM - AMI vs Number of Clusters")
ax.set(xlabel="Number of Clusters", ylabel="AMI")
plt.savefig('./Plots/madelon_em_ami.png')

fig = plt.figure()
ax = df.plot(y='HOM', title="Madelon - EM - Homogeneity vs Number of Clusters")
ax.set(xlabel="Number of Clusters", ylabel="Homogeneity")
plt.savefig('./Plots/madelon_em_homo.png')

fig = plt.figure()
ax = df.plot(y='COM', title="Madelon - EM - Completeness vs Number of Clusters")
ax.set(xlabel="Number of Clusters", ylabel="Completeness")
plt.savefig('./Plots/madelon_em_comp.png')

fig = plt.figure()
ax = df.plot(y='SIL', title="Madelon - EM - Silhouette Score vs Number of Clusters")
ax.set(xlabel="Number of Clusters", ylabel="Silhouette Score")
plt.savefig('./Plots/madelon_em_silh.png')
